# %%
from wave_client import WaveClient
import pandas as pd
from utils import (
    load_environment_variables,
)

# %%
# Load environment variables and connect to WAVE backend
RESEARCHER_API_KEY, EXPERIMENTEE_API_KEY, WAVE_BACKEND_URL = load_environment_variables()

print(f"🔍 Connecting to WAVE backend...")
print(f"📡 Backend URL: {WAVE_BACKEND_URL}")
print(f"🔑 Using Researcher API key ending in: ...{RESEARCHER_API_KEY[-4:]}")

client = WaveClient(api_key=RESEARCHER_API_KEY, base_url=WAVE_BACKEND_URL)
# Out:
# Present working directory: c:\Users\mcpro\OneDrive\Documents\WAVE LAB\Code\shadows_3afc\tools
# Loading environment variables from c:\Users\mcpro\OneDrive\Documents\WAVE LAB\Code\shadows_3afc\tools/.env
# 🔍 Connecting to WAVE backend...
# 📡 Backend URL: https://wave-backend-production-8781.up.railway.app
# 🔑 Using Researcher API key ending in: ...bsik

# %%
## use this (uncomment it) to see what commands exist 
## (allow the scrollable option at the bottom to see all commands)

# help(client.experiments)
# help(client.experiment_data)

# %%
# Get all experiments to see which one to analyze
experiments = await client.experiments.list(skip=0, limit=200)
print(f"Found {len(experiments)} experiments\n")

# Sort by creation date (most recent first) and show up to 5
# sorted_experiments = sorted(experiments, key=lambda x: x.get('created_at', ''), reverse=True)[:5]
# print(f"Showing {len(sorted_experiments)} most recent experiments (of {len(experiments)} total)\n")

# Display experiment info
for i, exp in enumerate(experiments, 1):
    print(f"{i}. Experiment UUID: {exp['uuid']}")
    print(f"   Description: {exp.get('description', 'N/A')}")
    print(f"   Type ID: {exp.get('experiment_type_id', 'N/A')}")
    print(f"   Created: {exp.get('created_at', 'N/A')[:10]}")
    print(f"   Tags: {', '.join(exp.get('tags', []))}")
    print("-" * 70)
# Out:
# Found 7 experiments
#
# 1. Experiment UUID: 0ef3dc5a-b6d2-4c17-90ee-e83880a15c5f
#    Description: shadow_afc_prod
#    Type ID: 6
#    Created: 2026-01-08
#    Tags:
# ----------------------------------------------------------------------
# 2. Experiment UUID: 56332cb3-b54a-4828-be3e-bbc786118885
#    Description: jspsych_circles_prod
#    Type ID: 7
#    Created: 2026-01-09
#    Tags:
# ----------------------------------------------------------------------
# 3. Experiment UUID: 530a5fd4-2485-4d88-9c83-5acead500b94
#    Description: surprisedelab_pos
#    Type ID: 11
#    Created: 2026-02-02
#    Tags:
# ----------------------------------------------------------------------
# 4. Experiment UUID: aeb293f8-2206-46a9-9d46-b21092526504
#    Description: shadows_afc_numtask_prod
#    Type ID: 12
#    Created: 2026-02-05
#    Tags:
# ----------------------------------------------------------------------
# 5. Experiment UUID: 4a1d1324-64ab-464f-9787-b19058002f11
#    Description: shadows_afc_shortnum_prod
#    Type ID: 13
#    Created: 2026-02-05
#    Tags:
# ----------------------------------------------------------------------
# 6. Experiment UUID: 6023b648-b34a-4a61-89e8-2589fb1b6e39
#    Description: epcd_cup_prod
#    Type ID: 15
#    Created: 2026-02-12
#    Tags:
# ----------------------------------------------------------------------
# 7. Experiment UUID: 3d22a808-1884-49b5-9b6d-74dbc4507e27
#    Description: shadows_afc_bevel_prod
#    Type ID: 16
#    Created: 2026-02-20
#    Tags:
# ----------------------------------------------------------------------

# %%
#ALTERNATE CODE BOX FOR SAVING PAST EXPERIMENTS 
selected_experiment_uuid = "4a1d1324-64ab-464f-9787-b19058002f11" 

# Get all data from that experiment
print(f"\n📊 Fetching data for experiment {selected_experiment_uuid}...")
experiment_data_df = await client.experiment_data.get_all_data(
    experiment_id=selected_experiment_uuid
)

print(f"Total records: {len(experiment_data_df)}")
# print(experiment_data_df)
# Out:
# 📊 Fetching data for experiment 4a1d1324-64ab-464f-9787-b19058002f11...
# Total records: 195

# %%
#ALTERNATE FOR SAVING PAST EXPERIMENTS
# Filter and save into .csv file
full_df = (experiment_data_df.query("not participant_id.str.contains('no_query')")
           .sort_values(by="timestamp",ascending=True))
full_df.to_csv("data/dataframe_full_V1_3.csv", index = False)

answer_df = full_df.query("trial_category == 'afcexpt'")
answer_df.to_csv("data/dataframe_answer_V1_3.csv", index = False)

# %%
# Put the necessary info into the variables below 
selected_experiment_uuid = "3d22a808-1884-49b5-9b6d-74dbc4507e27" 

# Get all data from that experiment
print(f"\n📊 Fetching data for experiment {selected_experiment_uuid}...")
experiment_data_df = await client.experiment_data.get_all_data(
    experiment_id=selected_experiment_uuid
)

print(f"Total records: {len(experiment_data_df)}")
# print(experiment_data_df)
# Out:
# 📊 Fetching data for experiment 3d22a808-1884-49b5-9b6d-74dbc4507e27...
# Total records: 410

# %%
# Filter and save into .csv file
full_df = (experiment_data_df.query("not participant_id.str.contains('no_query')")
           .sort_values(by="timestamp",ascending=True))
full_df.to_csv("data/dataframe_full.csv", index = False)

answer_df = full_df.query("trial_category == 'afcexpt'")
answer_df.to_csv("data/dataframe_answer.csv", index = False)

# %%
# Example of how to pull out only a few specific columns

selected_columns = answer_df[["response","response_time","chosen_image","target_object","target_shadow"]]
print(selected_columns)
# Out:
#     response  response_time chosen_image target_object target_shadow
# 395        0         4665.0    objB_shaB             B             A
# 390        2         2341.0    objB_shaB             B             A
# 385        2         3315.0    objD_shaD             B             C
# 376        2         5262.0    objD_shaD             B             C
# 375        3         4560.0    objC_shaC             B             D
# ..       ...            ...          ...           ...           ...
# 20         0         8861.0    objB_shaB             A             C
# 15         1         5681.0    objC_shaC             A             C
# 5          3         4653.0    objB_shaB             B             C
# 10         2         2754.0    objB_shaB             B             D
# 0          0         3501.0    objB_shaB             B             A
#
# [80 rows x 5 columns]
